# %%
# !pip install -r requirements.txt

# %%
import pandas as pd

# %%
test = pd.read_csv("./test.csv")
train = pd.read_csv("./train.csv")

# %%
train.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  3798-EPWRR  Female              1      No         No       2          Yes
# 1  0744-GKNGE  Female              0     Yes        Yes      64          Yes
# 2  1755-RMCXH    Male              0     Yes        Yes       2          Yes
# 3  8200-LGKSR    Male              0     Yes         No      71          Yes
# 4  4698-KVLLG  Female              1      No         No      51          Yes
#
#   MultipleLines InternetService       OnlineSecurity  ...  \
# 0            No             DSL                   No  ...
# 1           Yes     Fiber optic                  Yes  ...
# 2            No              No  No internet service  ...
# 3           Yes             DSL                  Yes  ...
# 4            No              No  No internet service  ...
#
#       DeviceProtection          TechSupport          StreamingTV  \
# 0                   No                   No                   No
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4507 entries, 0 to 4506
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        4507 non-null   object
#  1   gender            4507 non-null   object
#  2   SeniorCitizen     4507 non-null   int64
#  3   Partner           4507 non-null   object
#  4   Dependents        4507 non-null   object
#  5   tenure            4507 non-null   int64
#  6   PhoneService      4507 non-null   object
#  7   MultipleLines     4507 non-null   object
#  8   InternetService   4507 non-null   object
#  9   OnlineSecurity    4507 non-null   object
#  10  OnlineBackup      4507 non-null   object
#  11  DeviceProtection  4507 non-null   object
#  12  TechSupport       4507 non-null   object
#  13  StreamingTV       4507 non-null   object
#  14  StreamingMovies   4507 non-null   object
#  15  Contract          4507 non-null   object
# ...

# %%
for item in train.columns:
    print(item)
    print (train[item].unique())
# Out:
# customerID
# ['3798-EPWRR' '0744-GKNGE' '1755-RMCXH' ... '4896-CPRPF' '5092-STPKP'
#  '8853-TZDGH']
# gender
# ['Female' 'Male']
# SeniorCitizen
# [1 0]
# Partner
# ['No' 'Yes']
# Dependents
# ['No' 'Yes']
# tenure
# [ 2 64 71 51 23 27  4 38  5 49 32  9  1 10 33 41 39 53 14 17 20 67 43 50
#  19 66 34 65 56 72 22 69 35  8 21 62 70 24 31  6 63 11 59 15 46  0  7 58
#  16 55 42 13 25  3 26 47 48 61 28 68 57 37 45 40 60 30 44 36 29 54 18 12
#  52]
# PhoneService
# ['Yes' 'No']
# MultipleLines
# ['No' 'Yes' 'No phone service']
# InternetService
# ['DSL' 'Fiber optic' 'No']
# OnlineSecurity
# ['No' 'Yes' 'No internet service']
# OnlineBackup
# ['No' 'No internet service' 'Yes']
# DeviceProtection
# ['No' 'No internet service' 'Yes']
# TechSupport
# ['No' 'Yes' 'No internet service']
# StreamingTV
# ['No' 'No internet service' 'Yes']
# StreamingMovies
# ['No' 'No internet service' 'Yes']
# Contract
# ['Month-to-month' 'Two year' 'One year']
# PaperlessBilling
# ['No' 'Yes']
# PaymentMethod
# ...

# %%
train = train.drop('customerID', axis=1)

# %%
test = test.drop('customerID', axis=1)

# %%
for item in train.columns:
    print(item)
    print (train[item].unique())
columns_to_convert = ['Partner', 
                      'Dependents', 
                      'PhoneService', 
                      'PaperlessBilling', 
                      'Churn']

for item in columns_to_convert:
    train[item].replace(to_replace='Yes', value=1, inplace=True)
    train[item].replace(to_replace='No',  value=0, inplace=True)
train.head()
# Out:
# gender
# ['Female' 'Male']
# SeniorCitizen
# [1 0]
# Partner
# ['No' 'Yes']
# Dependents
# ['No' 'Yes']
# tenure
# [ 2 64 71 51 23 27  4 38  5 49 32  9  1 10 33 41 39 53 14 17 20 67 43 50
#  19 66 34 65 56 72 22 69 35  8 21 62 70 24 31  6 63 11 59 15 46  0  7 58
#  16 55 42 13 25  3 26 47 48 61 28 68 57 37 45 40 60 30 44 36 29 54 18 12
#  52]
# PhoneService
# ['Yes' 'No']
# MultipleLines
# ['No' 'Yes' 'No phone service']
# InternetService
# ['DSL' 'Fiber optic' 'No']
# OnlineSecurity
# ['No' 'Yes' 'No internet service']
# OnlineBackup
# ['No' 'No internet service' 'Yes']
# DeviceProtection
# ['No' 'No internet service' 'Yes']
# TechSupport
# ['No' 'Yes' 'No internet service']
# StreamingTV
# ['No' 'No internet service' 'Yes']
# StreamingMovies
# ['No' 'No internet service' 'Yes']
# Contract
# ['Month-to-month' 'Two year' 'One year']
# PaperlessBilling
# ['No' 'Yes']
# PaymentMethod
# ['Electronic check' 'Bank transfer (automatic)' 'Mailed check'
#  'Credit card (automatic)']
# ...

# %%
columns_to_convert = ['Partner', 
                      'Dependents', 
                      'PhoneService', 
                      'PaperlessBilling', 
                      'Churn']

for item in columns_to_convert:
    test[item].replace(to_replace='Yes', value=1, inplace=True)
    test[item].replace(to_replace='No',  value=0, inplace=True)

# %%
train = train.replace('Female', 0)

# %%
train = train.replace('Male', 1)

# %%
test = test.replace('Female', 0)
test = test.replace('Male', 1)

# %%
train.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              1        0           0       2             1
# 1       0              0        1           1      64             1
# 2       1              0        1           1       2             1
# 3       1              0        1           0      71             1
# 4       0              1        0           0      51             1
#
#   MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0            No             DSL                   No                   No
# 1           Yes     Fiber optic                  Yes                   No
# 2            No              No  No internet service  No internet service
# 3           Yes             DSL                  Yes                   No
# 4            No              No  No internet service  No internet service
#
#       DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
train['TotalCharges'] = train['TotalCharges'].replace(r'\s+', 0, regex=True)
train['TotalCharges'] = pd.to_numeric(train['TotalCharges'])

# %%
test['TotalCharges'] = test['TotalCharges'].replace(r'\s+', 0, regex=True)
test['TotalCharges'] = pd.to_numeric(test['TotalCharges'])

# %%
train.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              1        0           0       2             1
# 1       0              0        1           1      64             1
# 2       1              0        1           1       2             1
# 3       1              0        1           0      71             1
# 4       0              1        0           0      51             1
#
#   MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0            No             DSL                   No                   No
# 1           Yes     Fiber optic                  Yes                   No
# 2            No              No  No internet service  No internet service
# 3           Yes             DSL                  Yes                   No
# 4            No              No  No internet service  No internet service
#
#       DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4507 entries, 0 to 4506
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            4507 non-null   int64
#  1   SeniorCitizen     4507 non-null   int64
#  2   Partner           4507 non-null   int64
#  3   Dependents        4507 non-null   int64
#  4   tenure            4507 non-null   int64
#  5   PhoneService      4507 non-null   int64
#  6   MultipleLines     4507 non-null   object
#  7   InternetService   4507 non-null   object
#  8   OnlineSecurity    4507 non-null   object
#  9   OnlineBackup      4507 non-null   object
#  10  DeviceProtection  4507 non-null   object
#  11  TechSupport       4507 non-null   object
#  12  StreamingTV       4507 non-null   object
#  13  StreamingMovies   4507 non-null   object
#  14  Contract          4507 non-null   object
#  15  PaperlessBilling  4507 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelEncoder = LabelEncoder()
columns_to_encode = ['OnlineSecurity', 
                     'OnlineBackup', 
                     'DeviceProtection', 
                     'TechSupport', 
                     'StreamingTV', 
                     'StreamingMovies', 
                     'InternetService', 
                     'Contract', 
                     'PaymentMethod', 
                     'MultipleLines']
# mapping valori int
for column in columns_to_encode:
    train[column] = labelEncoder.fit_transform(train[column])

# %%
from sklearn.preprocessing import LabelEncoder
labelEncoder = LabelEncoder()
columns_to_encode = ['OnlineSecurity', 
                     'OnlineBackup', 
                     'DeviceProtection', 
                     'TechSupport', 
                     'StreamingTV', 
                     'StreamingMovies', 
                     'InternetService', 
                     'Contract', 
                     'PaymentMethod', 
                     'MultipleLines']
# mapping valori int
for column in columns_to_encode:
    test[column] = labelEncoder.fit_transform(test[column])

# %%
train.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              1        0           0       2             1
# 1       0              0        1           1      64             1
# 2       1              0        1           1       2             1
# 3       1              0        1           0      71             1
# 4       0              1        0           0      51             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              0                0               0             0
# 1              2                1               2             0
# 2              0                2               1             1
# 3              2                0               2             0
# 4              0                2               1             1
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4507 entries, 0 to 4506
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            4507 non-null   int64
#  1   SeniorCitizen     4507 non-null   int64
#  2   Partner           4507 non-null   int64
#  3   Dependents        4507 non-null   int64
#  4   tenure            4507 non-null   int64
#  5   PhoneService      4507 non-null   int64
#  6   MultipleLines     4507 non-null   int32
#  7   InternetService   4507 non-null   int64
#  8   OnlineSecurity    4507 non-null   int64
#  9   OnlineBackup      4507 non-null   int64
#  10  DeviceProtection  4507 non-null   int64
#  11  TechSupport       4507 non-null   int64
#  12  StreamingTV       4507 non-null   int64
#  13  StreamingMovies   4507 non-null   int64
#  14  Contract          4507 non-null   int64
#  15  PaperlessBilling  4507 non-null   int64
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
def heat_map():
    correlation = train.corr()
    plt.figure(figsize=(20,20))
    sns.heatmap(correlation, square=True,annot=True,cmap='cubehelix')
    plt.title('Correlation between different features')

# %%
heat_map()

# %%
train = train.drop('TotalCharges', axis=1)
train = train.drop('tenure', axis=1)

# %%
test = test.drop('TotalCharges', axis=1)
test = test.drop('tenure', axis=1)

# %%
heat_map()

# %%
train = train.drop('gender', axis=1)

# %%
train['Streaming'] = train['StreamingTV'] | train['StreamingMovies']
train = train.drop('StreamingTV', axis=1)
train = train.drop('StreamingMovies', axis=1)

# %%
test = test.drop('gender', axis=1)
test['Streaming'] = test['StreamingTV'] | test['StreamingMovies']
test = test.drop('StreamingTV', axis=1)
test = test.drop('StreamingMovies', axis=1)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4507 entries, 0 to 4506
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SeniorCitizen     4507 non-null   int64
#  1   Partner           4507 non-null   int64
#  2   Dependents        4507 non-null   int64
#  3   PhoneService      4507 non-null   int64
#  4   MultipleLines     4507 non-null   int32
#  5   InternetService   4507 non-null   int64
#  6   OnlineSecurity    4507 non-null   int64
#  7   OnlineBackup      4507 non-null   int64
#  8   DeviceProtection  4507 non-null   int64
#  9   TechSupport       4507 non-null   int64
#  10  Contract          4507 non-null   int64
#  11  PaperlessBilling  4507 non-null   int64
#  12  PaymentMethod     4507 non-null   int64
#  13  MonthlyCharges    4507 non-null   float64
#  14  Churn             4507 non-null   int64
#  15  Streaming         4507 non-null   int64
# ...

# %%
def bar_chart(feature):
    churned = train[train['Churn']==1][feature].value_counts()
    no_churn = train[train['Churn']==0][feature].value_counts()
    df = pd.DataFrame([no_churn,churned])
    df.index = ['No-churn','Churn']
    df.plot(kind='bar',stacked = True, figsize=(10,5))

# %%
bar_chart('SeniorCitizen')

# %%
receita = train.groupby(by = 'SeniorCitizen')['Churn'].mean()
receita
# Out:
# SeniorCitizen
# 0    0.242280
# 1    0.408078
# Name: Churn, dtype: float64

# %%
bar_chart('Partner')

# %%
receita = train.groupby(by = 'Partner')['Churn'].mean()
receita
# Out:
# Partner
# 0    0.328455
# 1    0.205128
# Name: Churn, dtype: float64

# %%
y_train = train["Churn"].copy()
X_train = train.drop("Churn",axis=1).copy()

y_test = test["Churn"].copy()
X_test = test.drop("Churn",axis=1).copy()
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(max_depth=4)
trainedtree = model.fit(X_train, y_train)

pred = model.predict(X_test)

print(accuracy_score(y_test, pred)*100)
print(model.score(X_test, y_test))
# Out:
# 77.7284826974268
# 0.7772848269742679
